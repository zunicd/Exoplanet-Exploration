# %%
# Update sklearn to prevent version mismatches
### !pip install sklearn --upgrade
# %conda install --update-deps scikit-learn
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... Solving environment: ...working...
#
# Updating blas is constricted by
#
# mkl_fft -> requires blas==1.0=mkl
# numpy -> requires blas==1.0=mkl
# numpy-base -> requires blas==1.0=mkl
# scikit-learn -> requires blas==1.0=mkl
# scipy -> requires blas==1.0=mkl
#
# If you are sure you want an update of your package either try `conda update --all` or install a specific version of the package you want using `conda install <pkg>=<version>`
#
# done
# done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
### !pip install joblib
# %conda install --update-deps joblib
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... Solving environment: ...working... done
# done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# Matplotlib for visualization
from matplotlib import pyplot as plt
# display plots in the notebook
# %matplotlib inline

# Seaborn for easier visualization
import seaborn as sns
sns.set_style('darkgrid')

# store elements as dictionary keys and their counts as dictionary values
from collections import Counter

# Set max number of columns to be displayed
pd.set_option('display.max_columns', 60)
#### pd.set_option('display.max_colwidth', 70)

# scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# Classification metrics
from sklearn.metrics import confusion_matrix, classification_report

# Over-sampling using SMOTE
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # Exploratory Analysis

# %% [markdown]
# ### Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  koi_time0bk_err2  koi_impact  koi_impact_err1  \
# 0          0.003520         -0.003520       0.586            0.059
# 1          0.000581         -0.000581       0.969            5.126
# 2          0.000115         -0.000115       1.276            0.115
# 3          0.001130         -0.001130       0.701            0.235
# 4          0.001900         -0.001900       0.762            0.139
#
#    koi_impact_err2  koi_duration  koi_duration_err1  koi_duration_err2  \
# 0           -0.443       4.50700            0.11600           -0.11600
# 1           -0.077       1.78220            0.03410           -0.03410
# 2           -0.092       2.40641            0.00537           -0.00537
# 3           -0.478       1.65450            0.04200           -0.04200
# 4           -0.532       3.14020            0.06730           -0.06730
#
#    koi_depth  koi_depth_err1  koi_depth_err2  koi_prad  koi_prad_err1  \
# 0      874.8            35.5           -35.5      2.83           0.32
# 1    10829.0           171.0          -171.0     14.60           3.92
# 2     8079.2            12.8           -12.8     33.46           8.50
# 3      603.3            16.9           -16.9      2.75           0.88
# 4      686.0            18.7           -18.7      2.77           0.90
#
#    koi_prad_err2  koi_teq  koi_insol  koi_insol_err1  koi_insol_err2  \
# 0          -0.19      443       9.11            2.87           -1.62
# 1          -1.31      638      39.30           31.04          -10.49
# 2          -2.83     1395     891.96          668.95         -230.35
# 3          -0.35     1406     926.16          874.33         -314.24
# 4          -0.30     1160     427.65          420.33         -136.70
#
#    koi_model_snr  koi_tce_plnt_num  koi_steff  koi_steff_err1  koi_steff_err2  \
# 0           25.8                 2       5455              81             -81
# 1           76.3                 1       5853             158            -176
# 2          505.6                 1       5805             157            -174
# 3           40.9                 1       6031             169            -211
# 4           40.2                 2       6046             189            -232
#
#    koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  koi_srad_err1  \
# 0      4.467           0.064          -0.096     0.927          0.105
# 1      4.544           0.044          -0.176     0.868          0.233
# 2      4.564           0.053          -0.168     0.791          0.201
# 3      4.438           0.070          -0.210     1.046          0.334
# 4      4.486           0.054          -0.229     0.972          0.315
#
#    koi_srad_err2         ra        dec  koi_kepmag
# 0         -0.061  291.93423  48.141651      15.347
# 1         -0.078  297.00482  48.134129      15.436
# 2         -0.067  285.53461  48.285210      15.597
# 3         -0.133  288.75488  48.226200      15.509
# 4         -0.105  296.28613  48.224670      15.714

# %%
# Confirm that there is no nulls
df.isna().sum().sum()
# Out:
# 0

# %%
# Information about data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6991 entries, 0 to 6990
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   koi_disposition    6991 non-null   object
#  1   koi_fpflag_nt      6991 non-null   int64
#  2   koi_fpflag_ss      6991 non-null   int64
#  3   koi_fpflag_co      6991 non-null   int64
#  4   koi_fpflag_ec      6991 non-null   int64
#  5   koi_period         6991 non-null   float64
#  6   koi_period_err1    6991 non-null   float64
#  7   koi_period_err2    6991 non-null   float64
#  8   koi_time0bk        6991 non-null   float64
#  9   koi_time0bk_err1   6991 non-null   float64
#  10  koi_time0bk_err2   6991 non-null   float64
#  11  koi_impact         6991 non-null   float64
#  12  koi_impact_err1    6991 non-null   float64
#  13  koi_impact_err2    6991 non-null   float64
#  14  koi_duration       6991 non-null   float64
#  15  koi_duration_err1  6991 non-null   float64
#  16  koi_duration_err2  6991 non-null   float64
#  17  koi_depth          6991 non-null   float64
#  18  koi_depth_err1     6991 non-null   float64
#  19  koi_depth_err2     6991 non-null   float64
#  20  koi_prad           6991 non-null   float64
#  21  koi_prad_err1      6991 non-null   float64
#  22  koi_prad_err2      6991 non-null   float64
#  23  koi_teq            6991 non-null   int64
#  24  koi_insol          6991 non-null   float64
#  25  koi_insol_err1     6991 non-null   float64
#  26  koi_insol_err2     6991 non-null   float64
#  27  koi_model_snr      6991 non-null   float64
#  28  koi_tce_plnt_num   6991 non-null   int64
#  29  koi_steff          6991 non-null   int64
#  30  koi_steff_err1     6991 non-null   int64
#  31  koi_steff_err2     6991 non-null   int64
#  32  koi_slogg          6991 non-null   float64
#  33  koi_slogg_err1     6991 non-null   float64
#  34  koi_slogg_err2     6991 non-null   float64
#  35  koi_srad           6991 non-null   float64
#  36  koi_srad_err1      6991 non-null   float64
#  37  koi_srad_err2      6991 non-null   float64
#  38  ra                 6991 non-null   float64
#  39  dec                6991 non-null   float64
#  40  koi_kepmag         6991 non-null   float64
# dtypes: float64(31), int64(9), object(1)
# memory usage: 2.2+ MB

# %% [markdown]
# ### Select Features (Columns)

# %% [markdown]
# Description of exoplanet dataset columns can be found [here](https://exoplanetarchive.ipac.caltech.edu/docs/API_kepcandidate_columns.html).

# %%
df.columns
# Out:
# Index(['koi_disposition', 'koi_fpflag_nt', 'koi_fpflag_ss', 'koi_fpflag_co',
#        'koi_fpflag_ec', 'koi_period', 'koi_period_err1', 'koi_period_err2',
#        'koi_time0bk', 'koi_time0bk_err1', 'koi_time0bk_err2', 'koi_impact',
#        'koi_impact_err1', 'koi_impact_err2', 'koi_duration',
#        'koi_duration_err1', 'koi_duration_err2', 'koi_depth', 'koi_depth_err1',
#        'koi_depth_err2', 'koi_prad', 'koi_prad_err1', 'koi_prad_err2',
#        'koi_teq', 'koi_insol', 'koi_insol_err1', 'koi_insol_err2',
#        'koi_model_snr', 'koi_tce_plnt_num', 'koi_steff', 'koi_steff_err1',
#        'koi_steff_err2', 'koi_slogg', 'koi_slogg_err1', 'koi_slogg_err2',
#        'koi_srad', 'koi_srad_err1', 'koi_srad_err2', 'ra', 'dec',
#        'koi_kepmag'],
#       dtype='object')

# %% [markdown]
# #### Remove Unnecessary Features

# %% [markdown]
# To make dataframe easily readable we will remove all uncertainties columns that are representing errors.

# %%
# Set features, drop all features representing errors
selected_features = df.drop(columns=list(df.filter(like='err')))
print(selected_features.shape)
selected_features.head()
# Out:
# (6991, 21)
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  \
# 0   54.418383   162.513840       0.586       4.50700      874.8      2.83
# 1   19.899140   175.850252       0.969       1.78220    10829.0     14.60
# 2    1.736952   170.307565       1.276       2.40641     8079.2     33.46
# 3    2.525592   171.595550       0.701       1.65450      603.3      2.75
# 4    4.134435   172.979370       0.762       3.14020      686.0      2.77
#
#    koi_teq  koi_insol  koi_model_snr  koi_tce_plnt_num  koi_steff  koi_slogg  \
# 0      443       9.11           25.8                 2       5455      4.467
# 1      638      39.30           76.3                 1       5853      4.544
# 2     1395     891.96          505.6                 1       5805      4.564
# 3     1406     926.16           40.9                 1       6031      4.438
# 4     1160     427.65           40.2                 2       6046      4.486
#
#    koi_srad         ra        dec  koi_kepmag
# 0     0.927  291.93423  48.141651      15.347
# 1     0.868  297.00482  48.134129      15.436
# 2     0.791  285.53461  48.285210      15.597
# 3     1.046  288.75488  48.226200      15.509
# 4     0.972  296.28613  48.224670      15.714

# %% [markdown]
# ### Data and Target Features

# %% [markdown]
# #### Defining Data and Target Features

# %%
# Define data features
X = selected_features.drop('koi_disposition', axis=1)

# Define feature_names for later use
feature_names = X.columns

# Define target feature
y = selected_features['koi_disposition']

print(X.shape, y.shape)
# Out:
# (6991, 20) (6991,)

# %% [markdown]
# ### Distributions of Data (Numeric) Features

# %% [markdown]
# #### Plotting the Histogram Grid

# %%
# Plot histogram grid
X.hist(figsize=(14,14))

plt.show()

# %% [markdown]
# From random forest feature performances, we could see that 4 koi_fpflag* (1 or 0) features are among first six important features (1, 2, 3, 6).

# %% [markdown]
# #### Summary Statistics for  Data Features

# %%
X.describe()
# Out:
#        koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# count    6991.000000    6991.000000    6991.000000    6991.000000
# mean        0.157059       0.244743       0.202975       0.125018
# std         0.363882       0.429966       0.402243       0.330763
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#         koi_period  koi_time0bk   koi_impact  koi_duration     koi_depth  \
# count  6991.000000  6991.000000  6991.000000   6991.000000  6.991000e+03
# mean     56.191248   164.488820     0.730631      5.549368  2.391190e+04
# std     117.570962    67.020475     3.346956      6.425205  8.241240e+04
# min       0.259820   120.515914     0.000000      0.167000  7.500000e+00
# 25%       2.620126   132.683917     0.198000      2.446000  1.604000e+02
# 50%       8.947426   136.739230     0.539000      3.793000  4.245000e+02
# 75%      34.282605   169.937005     0.891000      6.197500  1.533250e+03
# max    1071.232624  1472.522306   100.806000    138.540000  1.541400e+06
#
#             koi_prad       koi_teq     koi_insol  koi_model_snr  \
# count    6991.000000   6991.000000  6.991000e+03    6991.000000
# mean      121.194193   1095.152768  8.263769e+03     276.038764
# std      3519.737626    856.234809  1.775255e+05     824.788481
# min         0.140000     92.000000  2.000000e-02       1.600000
# 25%         1.400000    554.000000  2.227000e+01      12.400000
# 50%         2.420000    888.000000  1.466700e+02      23.700000
# 75%        15.965000   1397.500000  9.006700e+02      82.250000
# max    200346.000000  14667.000000  1.094755e+07    9054.700000
#
#        koi_tce_plnt_num     koi_steff    koi_slogg     koi_srad           ra  \
# count       6991.000000   6991.000000  6991.000000  6991.000000  6991.000000
# mean           1.233729   5700.682449     4.305049     1.740749   292.082406
# std            0.650089    802.060405     0.439238     5.903415     4.762908
# min            1.000000   2661.000000     0.047000     0.109000   279.856080
# 25%            1.000000   5297.000000     4.209000     0.829000   288.704730
# 50%            1.000000   5757.000000     4.436000     0.999000   292.314760
# 75%            1.000000   6110.000000     4.543000     1.357000   295.888550
# max            8.000000  15896.000000     5.364000   180.013000   301.720760
#
#                dec   koi_kepmag
# count  6991.000000  6991.000000
# mean     43.812143    14.271508
# std       3.606167     1.350802
# min      36.577381     6.966000
# 25%      40.797760    13.455000
# 50%      43.679661    14.534000
# 75%      46.693659    15.322000
# max      52.336010    19.065000

# %% [markdown]
# ### Correlations

# %%
# Calculate correlations between numeric features
correlations = X.corr()

correlations
# Out:
#                   koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# koi_fpflag_nt          1.000000      -0.241148       0.003062       0.050790
# koi_fpflag_ss         -0.241148       1.000000       0.144516       0.101695
# koi_fpflag_co          0.003062       0.144516       1.000000       0.538280
# koi_fpflag_ec          0.050790       0.101695       0.538280       1.000000
# koi_period             0.408724      -0.155964      -0.164792      -0.138946
# koi_time0bk            0.249381      -0.111469      -0.121452      -0.099760
# koi_impact             0.072748       0.042021       0.007501      -0.004913
# koi_duration           0.287118       0.014224      -0.048398       0.023232
# koi_depth             -0.043942       0.423883      -0.132939      -0.088001
# koi_prad               0.054410      -0.000752      -0.013284      -0.011078
# koi_teq               -0.003013       0.191842       0.259045       0.218624
# koi_insol             -0.000566       0.031315       0.018086       0.034874
# koi_model_snr         -0.079241       0.439764      -0.134479      -0.091905
# koi_tce_plnt_num       0.035902      -0.184721      -0.122911      -0.103976
# koi_steff              0.105008       0.104600       0.016750       0.012411
# koi_slogg             -0.128576      -0.053394      -0.012101       0.003066
# koi_srad               0.045535       0.032638       0.032129       0.022411
# ra                     0.030920       0.088010       0.159988       0.069693
# dec                   -0.046510      -0.053471      -0.094027      -0.045495
# koi_kepmag            -0.101643      -0.006009       0.067023       0.047932
#
#                   koi_period  koi_time0bk  koi_impact  koi_duration  \
# koi_fpflag_nt       0.408724     0.249381    0.072748      0.287118
# koi_fpflag_ss      -0.155964    -0.111469    0.042021      0.014224
# koi_fpflag_co      -0.164792    -0.121452    0.007501     -0.048398
# koi_fpflag_ec      -0.138946    -0.099760   -0.004913      0.023232
# koi_period          1.000000     0.655186    0.067571      0.324488
# koi_time0bk         0.655186     1.000000    0.055597      0.200979
# koi_impact          0.067571     0.055597    1.000000      0.038594
# koi_duration        0.324488     0.200979    0.038594      1.000000
# koi_depth          -0.064272    -0.037195    0.001088      0.072860
# koi_prad            0.072790     0.039814    0.738676      0.041484
# koi_teq            -0.390006    -0.315510   -0.012648     -0.182678
# koi_insol          -0.021743    -0.021307   -0.003793     -0.017367
# koi_model_snr      -0.081456    -0.058522   -0.002429      0.073401
# koi_tce_plnt_num   -0.022590    -0.006344   -0.006689     -0.011103
# koi_steff           0.021806     0.003641    0.013467      0.102602
# koi_slogg          -0.055410    -0.001929   -0.073798     -0.129763
# koi_srad            0.017590    -0.004831    0.030429      0.016414
# ra                 -0.030675    -0.016981    0.018979      0.038933
# dec                 0.011226     0.010483    0.000357     -0.034985
# koi_kepmag         -0.045959     0.021898   -0.000494     -0.100665
#
#                   koi_depth  koi_prad   koi_teq  koi_insol  koi_model_snr  \
# koi_fpflag_nt     -0.043942  0.054410 -0.003013  -0.000566      -0.079241
# koi_fpflag_ss      0.423883 -0.000752  0.191842   0.031315       0.439764
# koi_fpflag_co     -0.132939 -0.013284  0.259045   0.018086      -0.134479
# koi_fpflag_ec     -0.088001 -0.011078  0.218624   0.034874      -0.091905
# koi_period        -0.064272  0.072790 -0.390006  -0.021743      -0.081456
# koi_time0bk       -0.037195  0.039814 -0.315510  -0.021307      -0.058522
# koi_impact         0.001088  0.738676 -0.012648  -0.003793      -0.002429
# koi_duration       0.072860  0.041484 -0.182678  -0.017367       0.073401
# koi_depth          1.000000  0.000740  0.076197  -0.006029       0.588988
# koi_prad           0.000740  1.000000 -0.003743   0.002439      -0.003568
# koi_teq            0.076197 -0.003743  1.000000   0.430384       0.052079
# koi_insol         -0.006029  0.002439  0.430384   1.000000      -0.008181
# koi_model_snr      0.588988 -0.003568  0.052079  -0.008181       1.000000
# koi_tce_plnt_num  -0.094301 -0.005195 -0.082245  -0.008428      -0.104073
# koi_steff          0.124717 -0.014998  0.238593  -0.057948       0.152426
# koi_slogg         -0.010089 -0.105581 -0.525108  -0.280029      -0.043406
# koi_srad          -0.017221  0.061426  0.450489   0.565224      -0.013017
# ra                 0.019420  0.007930  0.112734   0.023957       0.029263
# dec               -0.016085  0.003478 -0.061653  -0.016428      -0.000514
# koi_kepmag         0.002357 -0.023326 -0.266714  -0.069369      -0.130196
#
#                   koi_tce_plnt_num  koi_steff  koi_slogg  koi_srad        ra  \
# koi_fpflag_nt             0.035902   0.105008  -0.128576  0.045535  0.030920
# koi_fpflag_ss            -0.184721   0.104600  -0.053394  0.032638  0.088010
# koi_fpflag_co            -0.122911   0.016750  -0.012101  0.032129  0.159988
# koi_fpflag_ec            -0.103976   0.012411   0.003066  0.022411  0.069693
# koi_period               -0.022590   0.021806  -0.055410  0.017590 -0.030675
# koi_time0bk              -0.006344   0.003641  -0.001929 -0.004831 -0.016981
# koi_impact               -0.006689   0.013467  -0.073798  0.030429  0.018979
# koi_duration             -0.011103   0.102602  -0.129763  0.016414  0.038933
# koi_depth                -0.094301   0.124717  -0.010089 -0.017221  0.019420
# koi_prad                 -0.005195  -0.014998  -0.105581  0.061426  0.007930
# koi_teq                  -0.082245   0.238593  -0.525108  0.450489  0.112734
# koi_insol                -0.008428  -0.057948  -0.280029  0.565224  0.023957
# koi_model_snr            -0.104073   0.152426  -0.043406 -0.013017  0.029263
# koi_tce_plnt_num          1.000000  -0.055340   0.031275  0.012990 -0.037044
# koi_steff                -0.055340   1.000000  -0.132349 -0.119217  0.113754
# koi_slogg                 0.031275  -0.132349   1.000000 -0.650854 -0.077364
# koi_srad                  0.012990  -0.119217  -0.650854  1.000000  0.040415
# ra                       -0.037044   0.113754  -0.077364  0.040415  1.000000
# dec                       0.027814  -0.039747   0.059115 -0.033598 -0.024534
# koi_kepmag               -0.051752  -0.338068   0.479006 -0.175329 -0.001263
#
#                        dec  koi_kepmag
# koi_fpflag_nt    -0.046510   -0.101643
# koi_fpflag_ss    -0.053471   -0.006009
# koi_fpflag_co    -0.094027    0.067023
# koi_fpflag_ec    -0.045495    0.047932
# koi_period        0.011226   -0.045959
# koi_time0bk       0.010483    0.021898
# koi_impact        0.000357   -0.000494
# koi_duration     -0.034985   -0.100665
# koi_depth        -0.016085    0.002357
# koi_prad          0.003478   -0.023326
# koi_teq          -0.061653   -0.266714
# koi_insol        -0.016428   -0.069369
# koi_model_snr    -0.000514   -0.130196
# koi_tce_plnt_num  0.027814   -0.051752
# koi_steff        -0.039747   -0.338068
# koi_slogg         0.059115    0.479006
# koi_srad         -0.033598   -0.175329
# ra               -0.024534   -0.001263
# dec               1.000000    0.025746
# koi_kepmag        0.025746    1.000000

# %% [markdown]
# It is difficult tos see any relationship from the above table.
#
# To get a better view of correlations we wiil create a heatmap plot

# %%
# Generate a mask for the upper triangle
corr_mask = np.zeros_like(correlations)
corr_mask[np.triu_indices_from(corr_mask)] = 1

# Make the figsize 9x9
plt.figure(figsize=(10,10))

# Plot heatmap of annotated correlations; change background to white
with sns.axes_style('white'):
    sns.heatmap(correlations*100, 
                cmap='RdBu_r', 
                annot=True,
                fmt='.0f',
                mask=corr_mask,
                cbar=False)
    
plt.title('Correlations', fontsize=14)
plt.yticks(rotation=0)
plt.xticks(rotation=45, horizontalalignment='right')
#plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Distributions of the Target Feature

# %%
# Frequency of target feature
y.value_counts()
# Out:
# FALSE POSITIVE    3504
# CONFIRMED         1800
# CANDIDATE         1687
# Name: koi_disposition, dtype: int64

# %% [markdown]
# Let's define a small helper funtcion which displays count and percentage per class of the target feature.

# %%
# Function to display count and percentage per class of target feature
def class_count(a):
    counter=Counter(a)
    kv=[list(counter.keys()),list(counter.values())]
    dff = pd.DataFrame(np.array(kv).T, columns=['koi_disposition','Count'])
    dff['Count'] = dff['Count'].astype('int64')
    dff['%'] = round(dff['Count'] / a.shape[0] * 100, 2)
    return dff.sort_values('Count',ascending=False)

# %%
# Let's use the function
class_count(y)
# Out:
#   koi_disposition  Count      %
# 1  FALSE POSITIVE   3504  50.12
# 0       CONFIRMED   1800  25.75
# 2       CANDIDATE   1687  24.13

# %%
# Define target_names for later use
target_names = sorted(list(class_count(y).koi_disposition.values))
target_names
# Out:
# ['CANDIDATE', 'CONFIRMED', 'FALSE POSITIVE']

# %%
# Class distribution for koi_disposition
sns.countplot(y)
plt.title('Distribution of koi_disposition classes')
plt.xlabel('koi_disposition', size=12)
plt.ylabel('Frequency', size=12)

plt.show()

# %% [markdown]
# Our dataset is slightly imbalanced. Using SMOTE technique did not make any improvement.

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42, stratify=y)
print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 4893 2098 4893 2098

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 1375              0              0              0              0    7.542358
# 386               0              0              0              0    6.581477
# 111               0              0              0              0    8.203970
# 3737              0              1              0              0   29.015853
# 6938              1              0              0              0  229.957537
#
#       koi_time0bk  koi_impact  koi_duration  koi_depth  koi_prad  koi_teq  \
# 1375   132.961170       0.318       4.73000      132.5      1.59     1054
# 386    174.787814       0.137       3.08960     2318.9      4.56      881
# 111    169.691380       0.823       2.96670     1024.4      3.01      742
# 3737   138.402477      12.223       7.19844    71432.0   1183.06      592
# 6938   326.018400       1.175       7.59000      400.0     43.78      444
#
#       koi_insol  koi_model_snr  koi_tce_plnt_num  koi_steff  koi_slogg  \
# 1375     292.19           25.8                 2       5711      4.221
# 386      142.63          116.2                 1       5188      4.400
# 111       71.50           54.4                 1       5015      4.499
# 3737      29.11         1268.8                 1       5783      4.415
# 6938       9.22           10.2                 1       6419      3.978
#
#       koi_srad         ra        dec  koi_kepmag
# 1375     1.391  283.19208  41.305389      13.353
# 386      0.973  297.31598  46.023258      15.471
# 111      0.826  286.56570  41.808399      15.376
# 3737     0.941  296.93976  42.691921      15.546
# 6938     2.057  295.97794  50.771481      10.505

# %%
y_test
# Out:
# 5233         CONFIRMED
# 269          CANDIDATE
# 6828         CANDIDATE
# 2209         CONFIRMED
# 6927    FALSE POSITIVE
#              ...
# 5408    FALSE POSITIVE
# 5683    FALSE POSITIVE
# 6450         CANDIDATE
# 6238    FALSE POSITIVE
# 4987         CANDIDATE
# Name: koi_disposition, Length: 2098, dtype: object

# %%
# Check class distribution for y_test
class_count(y_test)
# Out:
#   koi_disposition  Count      %
# 2  FALSE POSITIVE   1052  50.14
# 0       CONFIRMED    540  25.74
# 1       CANDIDATE    506  24.12

# %%
# Check class distribution for y_test
class_count(y_train)
# Out:
#   koi_disposition  Count      %
# 1  FALSE POSITIVE   2452  50.11
# 0       CONFIRMED   1260  25.75
# 2       CANDIDATE   1181  24.14

# %% [markdown]
# They seem equally distributed.

# %% [markdown]
# # Pre-processing

# %% [markdown]
# ### Scaling

# %% [markdown]
# Scale the data using the MinMaxScaler

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(random_state=10)
rfc.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(random_state=10)

# %%
RFC_Train_Score = rfc.score(X_train_scaled, y_train)
RFC_Test_Score = rfc.score(X_test_scaled, y_test)                        
print(f"Training Data Score: {RFC_Train_Score}")
print(f"Testing Data Score: {RFC_Test_Score}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.9032411820781697

# %%
# Predictions
pred = rfc.predict(X_test_scaled)
pred
# Out:
# array(['CANDIDATE', 'CONFIRMED', 'CANDIDATE', ..., 'CANDIDATE',
#        'FALSE POSITIVE', 'CANDIDATE'], dtype=object)

# %%
pd.DataFrame({"Prediction": pred, "Actual": y_test}).reset_index(drop=True)
# Out:
#           Prediction          Actual
# 0          CANDIDATE       CONFIRMED
# 1          CONFIRMED       CANDIDATE
# 2          CANDIDATE       CANDIDATE
# 3          CONFIRMED       CONFIRMED
# 4     FALSE POSITIVE  FALSE POSITIVE
# ...              ...             ...
# 2093  FALSE POSITIVE  FALSE POSITIVE
# 2094  FALSE POSITIVE  FALSE POSITIVE
# 2095       CANDIDATE       CANDIDATE
# 2096  FALSE POSITIVE  FALSE POSITIVE
# 2097       CANDIDATE       CANDIDATE
#
# [2098 rows x 2 columns]

# %% [markdown]
# ### Validation

# %% [markdown]
# Let' start with confusion matrix

# %%
cm = confusion_matrix(y_test, pred)
print(cm)
# Out:
# [[ 398  101    7]
#  [  84  446   10]
#  [   1    0 1051]]

# %% [markdown]
# Our data is sltghtly imbalanced so we will use normalized confusion matrix as well.

# %%
# Normalized confusion matrix
cm = np.around(cm / cm.sum(axis=1)[:, np.newaxis], 2)
print(cm)
# Out:
# [[0.79 0.2  0.01]
#  [0.16 0.83 0.02]
#  [0.   0.   1.  ]]

# %% [markdown]
# It is not so easy to get the storu from just numbers.
#
# This is why hy we will create a heatmap plot for both matrices sid e by side.

# %%
# Function to display confusion matrix and its normalized copy side by side
def plot_conf_mat_w_and_wo_norm(model):
    f, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))
    f.suptitle(model, fontsize=14)
    f.subplots_adjust(top=0.85, wspace=0.2)

    # confusion matrix without normalization
    mat = confusion_matrix(y_test, pred)
    sns.heatmap(mat,
                annot=True,
                annot_kws=dict(fontsize=14),
                fmt='d',
                cbar=True,
                square=True,
                cmap='Reds',
                ax=ax1)

    ax1.set_xticklabels(labels=target_names, size=9)
    ax1.set_yticklabels(labels=target_names, size=9, va='center')
    ax1.set_title('Confusion Matrix w/o Normalization')
    ax1.set_xlabel('Predicted Labels', size=12)
    ax1.set_ylabel('True Labels', size=12)

    # normalized confusion matrix
    matn = mat / mat.sum(axis=1)[:, np.newaxis]
    sns.heatmap(matn,
                annot=True,
                annot_kws=dict(fontsize=14),
                fmt='.2f',
                cbar=True,
                square=True,
                cmap='Reds',
                vmin = 0,
                vmax = 1,
                ax=ax2)

    ax2.set_xticklabels(labels=target_names, size=9)
    ax2.set_yticklabels(labels=target_names, size=9, va='center')
    ax2.set_title('Normalized Confusion Matrix')
    ax2.set_xlabel('Predicted Labels', size=12)
    ax2.set_ylabel('True Labels', size=12)

    plt.show()

# %%
model = 'Random Forest'
plot_conf_mat_w_and_wo_norm(model)

# %%
# Display classification report
print(classification_report(y_test, pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.82      0.79      0.80       506
#      CONFIRMED       0.82      0.83      0.82       540
# FALSE POSITIVE       0.98      1.00      0.99      1052
#
#       accuracy                           0.90      2098
#      macro avg       0.87      0.87      0.87      2098
#   weighted avg       0.90      0.90      0.90      2098

# %% [markdown]
# "False Positive" are almost 100% predicted, but part of that could be caused by imbalanced dataset. "Candidate" has a slightly worse recall than "Confirmed".

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
rfc_ht = RandomForestClassifier(random_state=10)

# %%
# Create the GridSearchCV model
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators': [100, 200, 300, 400],
              'max_features': ['sqrt', 0.33],
              'criterion': ['gini', 'entropy']}
grid = GridSearchCV(rfc_ht, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] criterion=gini, max_features=sqrt, n_estimators=100 .............
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  criterion=gini, max_features=sqrt, n_estimators=100, score=0.898, total=   0.7s
# [CV] criterion=gini, max_features=sqrt, n_estimators=100 .............
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [CV]  criterion=gini, max_features=sqrt, n_estimators=100, score=0.895, total=   0.7s
# [CV] criterion=gini, max_features=sqrt, n_estimators=100 .............
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    1.4s remaining:    0.0s
# [CV]  criterion=gini, max_features=sqrt, n_estimators=100, score=0.892, total=   0.7s
# [CV] criterion=gini, max_features=sqrt, n_estimators=100 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=100, score=0.899, total=   0.7s
# [CV] criterion=gini, max_features=sqrt, n_estimators=100 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=100, score=0.889, total=   0.7s
# [CV] criterion=gini, max_features=sqrt, n_estimators=200 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=200, score=0.903, total=   1.5s
# [CV] criterion=gini, max_features=sqrt, n_estimators=200 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=200, score=0.894, total=   1.4s
# [CV] criterion=gini, max_features=sqrt, n_estimators=200 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=200, score=0.892, total=   1.5s
# [CV] criterion=gini, max_features=sqrt, n_estimators=200 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=200, score=0.899, total=   1.5s
# [CV] criterion=gini, max_features=sqrt, n_estimators=200 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=200, score=0.885, total=   1.5s
# [CV] criterion=gini, max_features=sqrt, n_estimators=300 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=300, score=0.904, total=   2.2s
# [CV] criterion=gini, max_features=sqrt, n_estimators=300 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=300, score=0.896, total=   2.1s
# [CV] criterion=gini, max_features=sqrt, n_estimators=300 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=300, score=0.894, total=   2.2s
# [CV] criterion=gini, max_features=sqrt, n_estimators=300 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=300, score=0.897, total=   2.2s
# [CV] criterion=gini, max_features=sqrt, n_estimators=300 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=300, score=0.884, total=   2.2s
# [CV] criterion=gini, max_features=sqrt, n_estimators=400 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=400, score=0.904, total=   2.9s
# [CV] criterion=gini, max_features=sqrt, n_estimators=400 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=400, score=0.892, total=   2.9s
# [CV] criterion=gini, max_features=sqrt, n_estimators=400 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=400, score=0.895, total=   2.9s
# [CV] criterion=gini, max_features=sqrt, n_estimators=400 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=400, score=0.897, total=   2.9s
# [CV] criterion=gini, max_features=sqrt, n_estimators=400 .............
# [CV]  criterion=gini, max_features=sqrt, n_estimators=400, score=0.884, total=   2.9s
# [CV] criterion=gini, max_features=0.33, n_estimators=100 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=100, score=0.903, total=   1.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=100 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=100, score=0.885, total=   1.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=100 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=100, score=0.892, total=   1.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=100 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=100, score=0.902, total=   1.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=100 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=100, score=0.885, total=   1.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=200 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=200, score=0.905, total=   2.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=200 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=200, score=0.886, total=   2.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=200 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=200, score=0.894, total=   2.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=200 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=200, score=0.906, total=   2.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=200 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=200, score=0.890, total=   2.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=300 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=300, score=0.905, total=   3.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=300 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=300, score=0.888, total=   2.9s
# [CV] criterion=gini, max_features=0.33, n_estimators=300 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=300, score=0.895, total=   3.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=300 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=300, score=0.906, total=   2.9s
# [CV] criterion=gini, max_features=0.33, n_estimators=300 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=300, score=0.885, total=   3.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=400 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=400, score=0.904, total=   4.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=400 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=400, score=0.887, total=   3.9s
# [CV] criterion=gini, max_features=0.33, n_estimators=400 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=400, score=0.895, total=   4.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=400 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=400, score=0.904, total=   4.0s
# [CV] criterion=gini, max_features=0.33, n_estimators=400 .............
# [CV]  criterion=gini, max_features=0.33, n_estimators=400, score=0.887, total=   3.9s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=100 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=100, score=0.904, total=   1.1s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=100 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=100, score=0.898, total=   1.1s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=100 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=100, score=0.896, total=   1.2s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=100 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=100, score=0.897, total=   1.1s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=100 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=100, score=0.888, total=   1.1s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=200 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=200, score=0.900, total=   2.2s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=200 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=200, score=0.895, total=   2.2s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=200 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=200, score=0.893, total=   2.2s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=200 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=200, score=0.895, total=   2.2s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=200 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=200, score=0.891, total=   2.2s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=300 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=300, score=0.900, total=   3.3s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=300 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=300, score=0.894, total=   3.3s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=300 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=300, score=0.896, total=   3.3s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=300 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=300, score=0.892, total=   3.4s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=300 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=300, score=0.889, total=   3.3s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=400 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=400, score=0.900, total=   4.4s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=400 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=400, score=0.895, total=   4.4s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=400 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=400, score=0.896, total=   4.4s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=400 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=400, score=0.894, total=   4.4s
# [CV] criterion=entropy, max_features=sqrt, n_estimators=400 ..........
# [CV]  criterion=entropy, max_features=sqrt, n_estimators=400, score=0.889, total=   4.4s
# [CV] criterion=entropy, max_features=0.33, n_estimators=100 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=100, score=0.892, total=   1.5s
# [CV] criterion=entropy, max_features=0.33, n_estimators=100 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=100, score=0.890, total=   1.5s
# [CV] criterion=entropy, max_features=0.33, n_estimators=100 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=100, score=0.899, total=   1.5s
# [CV] criterion=entropy, max_features=0.33, n_estimators=100 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=100, score=0.899, total=   1.5s
# [CV] criterion=entropy, max_features=0.33, n_estimators=100 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=100, score=0.889, total=   1.5s
# [CV] criterion=entropy, max_features=0.33, n_estimators=200 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=200, score=0.899, total=   2.9s
# [CV] criterion=entropy, max_features=0.33, n_estimators=200 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=200, score=0.895, total=   2.9s
# [CV] criterion=entropy, max_features=0.33, n_estimators=200 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=200, score=0.899, total=   3.0s
# [CV] criterion=entropy, max_features=0.33, n_estimators=200 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=200, score=0.897, total=   3.0s
# [CV] criterion=entropy, max_features=0.33, n_estimators=200 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=200, score=0.890, total=   3.0s
# [CV] criterion=entropy, max_features=0.33, n_estimators=300 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=300, score=0.902, total=   4.4s
# [CV] criterion=entropy, max_features=0.33, n_estimators=300 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=300, score=0.894, total=   4.4s
# [CV] criterion=entropy, max_features=0.33, n_estimators=300 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=300, score=0.898, total=   4.5s
# [CV] criterion=entropy, max_features=0.33, n_estimators=300 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=300, score=0.898, total=   4.5s
# [CV] criterion=entropy, max_features=0.33, n_estimators=300 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=300, score=0.894, total=   4.5s
# [CV] criterion=entropy, max_features=0.33, n_estimators=400 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=400, score=0.901, total=   5.9s
# [CV] criterion=entropy, max_features=0.33, n_estimators=400 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=400, score=0.893, total=   6.0s
# [CV] criterion=entropy, max_features=0.33, n_estimators=400 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=400, score=0.896, total=   6.1s
# [CV] criterion=entropy, max_features=0.33, n_estimators=400 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=400, score=0.898, total=   6.0s
# [CV] criterion=entropy, max_features=0.33, n_estimators=400 ..........
# [CV]  criterion=entropy, max_features=0.33, n_estimators=400, score=0.893, total=   5.9s
# [Parallel(n_jobs=1)]: Done  80 out of  80 | elapsed:  3.6min finished
# GridSearchCV(estimator=RandomForestClassifier(random_state=10),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': ['sqrt', 0.33],
#                          'n_estimators': [100, 200, 300, 400]},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'criterion': 'entropy', 'max_features': 0.33, 'n_estimators': 300}
# 0.8969951810097948

# %%
# Define the best estimator, it will be needed for feature importance
# but we can use it instead of grid anywhere else as well
rfg = grid.best_estimator_

# %%
print(f"Training Data Score: {rfg.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {rfg.score(X_test_scaled, y_test)}")
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.9080076263107721

# %%
# Predictions
pred = rfg.predict(X_test_scaled)
pred
# Out:
# array(['CANDIDATE', 'CONFIRMED', 'CANDIDATE', ..., 'CANDIDATE',
#        'FALSE POSITIVE', 'CANDIDATE'], dtype=object)

# %%
pd.DataFrame({"Prediction": pred, "Actual": y_test}).reset_index(drop=True)
# Out:
#           Prediction          Actual
# 0          CANDIDATE       CONFIRMED
# 1          CONFIRMED       CANDIDATE
# 2          CANDIDATE       CANDIDATE
# 3          CONFIRMED       CONFIRMED
# 4     FALSE POSITIVE  FALSE POSITIVE
# ...              ...             ...
# 2093  FALSE POSITIVE  FALSE POSITIVE
# 2094  FALSE POSITIVE  FALSE POSITIVE
# 2095       CANDIDATE       CANDIDATE
# 2096  FALSE POSITIVE  FALSE POSITIVE
# 2097       CANDIDATE       CANDIDATE
#
# [2098 rows x 2 columns]

# %% [markdown]
# ### Validation after Greadsearch

# %%
# Display classification report
print(classification_report(y_test, pred, target_names=target_names))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.84      0.78      0.81       506
#      CONFIRMED       0.81      0.85      0.83       540
# FALSE POSITIVE       0.99      1.00      0.99      1052
#
#       accuracy                           0.91      2098
#      macro avg       0.88      0.88      0.88      2098
#   weighted avg       0.91      0.91      0.91      2098

# %% [markdown]
# ### Validation

# %%
plot_conf_mat_w_and_wo_norm(model)

# %%
class_count(y_test)
# Out:
#   koi_disposition  Count      %
# 2  FALSE POSITIVE   1052  50.14
# 0       CONFIRMED    540  25.74
# 1       CANDIDATE    506  24.12

# %%
class_count(pred)
# Out:
#   koi_disposition  Count      %
# 2  FALSE POSITIVE   1064  50.71
# 1       CONFIRMED    565  26.93
# 0       CANDIDATE    469  22.35

# %% [markdown]
# ### Feature Importances

# %%
# Rank the features by importance
feat_imp = pd.Series(rfg.feature_importances_, feature_names).sort_values(ascending=False)
feat_imp
# Out:
# koi_fpflag_co       0.154695
# koi_fpflag_nt       0.148109
# koi_fpflag_ss       0.126645
# koi_model_snr       0.119176
# koi_prad            0.066924
# koi_fpflag_ec       0.049719
# koi_depth           0.042457
# koi_period          0.040658
# koi_impact          0.032937
# koi_duration        0.029541
# koi_teq             0.024924
# koi_time0bk         0.024006
# koi_insol           0.021327
# ra                  0.020455
# dec                 0.018944
# koi_steff           0.018800
# koi_kepmag          0.018096
# koi_srad            0.017504
# koi_slogg           0.016930
# koi_tce_plnt_num    0.008152
# dtype: float64

# %%
# Plot feature importances
plt.figure(figsize=(10,5))
feat_imp.plot(kind='bar', fontsize=12)
plt.ylabel('Feature Importance Score', fontsize=12)
plt.title('Feature Importances', fontsize=14)
plt.show()

# %% [markdown]
# We are going to drop features starting from the worst ranked feature. In each iteration we will add one more feature and scale, train and score data.

# %%
for n in range(1, 15):
    fd = feat_imp.index.tolist()[-n:]

    X_if_train = X_train.drop(columns=fd) 
    X_if_test = X_test.drop(columns=fd)
    y_if_train = y_train
    y_if_test = y_test
    
    X_if_scaler = MinMaxScaler().fit(X_if_train)
    X_if_train_scaled = X_if_scaler.transform(X_if_train)
    X_if_test_scaled = X_if_scaler.transform(X_if_test)

    rfc_if = RandomForestClassifier(random_state=10, criterion='entropy', 
                                    max_features=0.33, n_estimators=300)
    rfc_if.fit(X_if_train_scaled, y_if_train)

    print("=" * 30)
    print(f"Number of dropped Features: {n}")
    ## print(f"Training Data Score: {rfc_if.score(X_if_train_scaled, y_if_train)}")
    print(f"Testing Data Score: {rfc_if.score(X_if_test_scaled, y_if_test)}")
# Out:
# ==============================
# Number of dropped Features: 1
# Testing Data Score: 0.9065776930409915
# ==============================
# Number of dropped Features: 2
# Testing Data Score: 0.9075309818875119
# ==============================
# Number of dropped Features: 3
# Testing Data Score: 0.9084842707340324
# ==============================
# Number of dropped Features: 4
# Testing Data Score: 0.9041944709246902
# ==============================
# Number of dropped Features: 5
# Testing Data Score: 0.9041944709246902
# ==============================
# Number of dropped Features: 6
# Testing Data Score: 0.899904671115348
# ==============================
# Number of dropped Features: 7
# Testing Data Score: 0.897998093422307
# ==============================
# Number of dropped Features: 8
# Testing Data Score: 0.9008579599618685
# ==============================
# Number of dropped Features: 9
# Testing Data Score: 0.8965681601525262
# ==============================
# Number of dropped Features: 10
# Testing Data Score: 0.9046711153479504
# ==============================
# Number of dropped Features: 11
# Testing Data Score: 0.9003813155386082
# ==============================
# Number of dropped Features: 12
# Testing Data Score: 0.8898951382268827
# ==============================
# Number of dropped Features: 13
# Testing Data Score: 0.8794089609151573
# ==============================
# Number of dropped Features: 14
# Testing Data Score: 0.8760724499523356

# %% [markdown]
# The score was almost all the time around 90%. It started going down after 12 features were dropped. Before that score varied and once went above our base score.

# %% [markdown]
# ## Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib

# We are saving our grid model
filename = 'damir_zunic_random_forest.sav'
joblib.dump(rfg, filename)
# Out:
# ['damir_zunic_random_forest.sav']

# %% [markdown]
# ## Loading the Model

# %%
# load the model
rf_model = joblib.load(filename)
print(rf_model.score(X_test_scaled, y_test))
# Out:
# 0.9080076263107721
